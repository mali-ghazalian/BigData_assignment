# %% [markdown]
# ---
# ---
# <strong style="font-size:42pt;">Eclat</strong>
#
# ---
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
with open('../q3/browsing.txt', 'r') as file:
    data = file.readlines()
    
baskets = []
for line in data:
    baskets.append([product for product in line.split()])

# %%
class Eclat:
    def __init__(self, min_support=100):
        self.min_support = min_support
        self.itemsets = []

    def fit(self, transactions):
        self.transactions = transactions
        self.min_support_count = self.min_support
        self.items = self._get_items()
        self._eclat([], list(self.items.keys()))

    def _get_items(self):
        items = {}
        for i, transaction in enumerate(self.transactions):
            for item in transaction:
                if item not in items:
                    items[item] = set()
                items[item].add(i)
        return items

    def _eclat(self, prefix, items):
        while items:
            item = items.pop(0)
            new_prefix = prefix + [item]
            item_support = self.items[item]

            if len(item_support) >= self.min_support_count:
                self.itemsets.append((new_prefix, len(item_support)))
                suffix_items = []
                for i in range(len(items)):
                    new_item_support = item_support & self.items[items[i]]
                    if len(new_item_support) >= self.min_support_count:
                        suffix_items.append(items[i])
                        self.items[items[i]] = new_item_support
                self._eclat(new_prefix, suffix_items)

    def get_itemsets(self):
        return self.itemsets

# %%
def get_full_support(itemset, transactions):
    count = 0
    for transaction in transactions:
        if set(itemset).issubset(set(transaction)):
            count += 1
    return count

# %%
eclat = Eclat(min_support=100)
eclat.fit(baskets)
frequent_itemsets = eclat.get_itemsets()

frequent_itemsets_dict = {tuple(sorted(itemset)): support for itemset, support in frequent_itemsets}

# %%
print("Frequent itemsets:")
for itemset, support in frequent_itemsets:
    print(f"Itemset: {itemset}, Support: {support}")
# Out:
# Frequent itemsets:
# Itemset: ['FRO11987'], Support: 104
# Itemset: ['ELE17451'], Support: 3875
# Itemset: ['ELE17451', 'SNA90258'], Support: 113
# Itemset: ['ELE17451', 'GRO99222'], Support: 148
# Itemset: ['ELE17451', 'ELE26917'], Support: 314
# Itemset: ['ELE17451', 'ELE26917', 'DAI62779'], Support: 160
# Itemset: ['ELE17451', 'SNA30755'], Support: 111
# Itemset: ['ELE17451', 'GRO73461'], Support: 580
# Itemset: ['ELE17451', 'GRO73461', 'GRO30386'], Support: 103
# Itemset: ['ELE17451', 'GRO73461', 'FRO40251'], Support: 159
# Itemset: ['ELE17451', 'GRO73461', 'DAI75645'], Support: 121
# Itemset: ['ELE17451', 'DAI22896'], Support: 193
# Itemset: ['ELE17451', 'SNA99873'], Support: 270
# Itemset: ['ELE17451', 'GRO56989'], Support: 129
# Itemset: ['ELE17451', 'FRO78087'], Support: 218
# Itemset: ['ELE17451', 'ELE59935'], Support: 181
# Itemset: ['ELE17451', 'DAI22177'], Support: 203
# Itemset: ['ELE17451', 'ELE66810'], Support: 154
# Itemset: ['ELE17451', 'GRO94758'], Support: 227
# Itemset: ['ELE17451', 'SNA55952'], Support: 123
# Itemset: ['ELE17451', 'DAI48891'], Support: 121
# Itemset: ['ELE17451', 'ELE11111'], Support: 121
# Itemset: ['ELE17451', 'FRO92261'], Support: 127
# Itemset: ['ELE17451', 'FRO32293'], Support: 219
# Itemset: ['ELE17451', 'DAI95741'], Support: 102
# Itemset: ['ELE17451', 'GRO30386'], Support: 103
# Itemset: ['ELE17451', 'FRO16142'], Support: 152
# Itemset: ['ELE17451', 'DAI35347'], Support: 158
# Itemset: ['ELE17451', 'SNA93860'], Support: 182
# Itemset: ['ELE17451', 'SNA72163'], Support: 272
# Itemset: ['ELE17451', 'SNA72163', 'SNA59903'], Support: 127
# Itemset: ['ELE17451', 'SNA72163', 'DAI88807'], Support: 105
# Itemset: ['ELE17451', 'DAI55911'], Support: 127
# Itemset: ['ELE17451', 'FRO31317'], Support: 359
# Itemset: ['ELE17451', 'SNA59903'], Support: 127
# Itemset: ['ELE17451', 'GRO15017'], Support: 171
# Itemset: ['ELE17451', 'FRO98184'], Support: 112
# Itemset: ['ELE17451', 'GRO59710'], Support: 408
# Itemset: ['ELE17451', 'GRO59710', 'ELE32164'], Support: 202
# Itemset: ['ELE17451', 'GRO59710', 'ELE32164', 'DAI43223'], Support: 101
# Itemset: ['ELE17451', 'GRO59710', 'DAI43223'], Support: 101
# Itemset: ['ELE17451', 'DAI63921'], Support: 188
# Itemset: ['ELE17451', 'SNA18336'], Support: 267
# Itemset: ['ELE17451', 'SNA18336', 'ELE92920'], Support: 228
# Itemset: ['ELE17451', 'SNA18336', 'ELE92920', 'DAI85309'], Support: 106
# Itemset: ['ELE17451', 'SNA18336', 'DAI85309'], Support: 106
# Itemset: ['ELE17451', 'ELE66600'], Support: 168
# Itemset: ['ELE17451', 'DAI91290'], Support: 219
# Itemset: ['ELE17451', 'ELE14480'], Support: 146
# Itemset: ['ELE17451', 'DAI62779'], Support: 160
# Itemset: ['ELE17451', 'SNA55762'], Support: 303
# Itemset: ['ELE17451', 'ELE68605'], Support: 115
# Itemset: ['ELE17451', 'SNA45677'], Support: 304
# Itemset: ['ELE17451', 'ELE12792'], Support: 159
# Itemset: ['ELE17451', 'FRO40251'], Support: 159
# Itemset: ['ELE17451', 'GRO85051'], Support: 217
# Itemset: ['ELE17451', 'GRO85051', 'SNA80324'], Support: 158
# Itemset: ['ELE17451', 'ELE20398'], Support: 111
# Itemset: ['ELE17451', 'GRO69543'], Support: 128
# Itemset: ['ELE17451', 'GRO61133'], Support: 209
# Itemset: ['ELE17451', 'GRO81087'], Support: 262
# Itemset: ['ELE17451', 'GRO35122'], Support: 154
# Itemset: ['ELE17451', 'ELE37770'], Support: 100
# Itemset: ['ELE17451', 'ELE53126'], Support: 151
# Itemset: ['ELE17451', 'ELE32164'], Support: 202
# Itemset: ['ELE17451', 'ELE32164', 'DAI43223'], Support: 101
# Itemset: ['ELE17451', 'DAI88807'], Support: 105
# Itemset: ['ELE17451', 'ELE37048'], Support: 135
# Itemset: ['ELE17451', 'ELE62598'], Support: 153
# Itemset: ['ELE17451', 'GRO21487'], Support: 236
# Itemset: ['ELE17451', 'DAI43223'], Support: 101
# Itemset: ['ELE17451', 'FRO66272'], Support: 117
# Itemset: ['ELE17451', 'SNA59061'], Support: 100
# Itemset: ['ELE17451', 'DAI88352'], Support: 105
# Itemset: ['ELE17451', 'DAI88079'], Support: 124
# Itemset: ['ELE17451', 'SNA80324'], Support: 158
# Itemset: ['ELE17451', 'SNA88283'], Support: 169
# Itemset: ['ELE17451', 'DAI75645'], Support: 121
# Itemset: ['ELE17451', 'FRO92469'], Support: 165
# Itemset: ['ELE17451', 'GRO38814'], Support: 160
# Itemset: ['ELE17451', 'ELE99737'], Support: 151
# Itemset: ['ELE17451', 'SNA96271'], Support: 203
# Itemset: ['ELE17451', 'FRO35904'], Support: 148
# Itemset: ['ELE17451', 'FRO85978'], Support: 173
# Itemset: ['ELE17451', 'FRO53271'], Support: 182
# Itemset: ['ELE17451', 'SNA90094'], Support: 182
# Itemset: ['ELE17451', 'SNA38068'], Support: 185
# Itemset: ['ELE17451', 'ELE74009'], Support: 231
# Itemset: ['ELE17451', 'GRO56726'], Support: 218
# Itemset: ['ELE17451', 'FRO89565'], Support: 104
# Itemset: ['ELE17451', 'ELE34057'], Support: 168
# Itemset: ['ELE17451', 'FRO75586'], Support: 151
# Itemset: ['ELE17451', 'ELE56788'], Support: 208
# Itemset: ['ELE17451', 'DAI31081'], Support: 230
# Itemset: ['ELE17451', 'GRO88324'], Support: 117
# Itemset: ['ELE17451', 'DAI83733'], Support: 296
# Itemset: ['ELE17451', 'FRO80039'], Support: 356
# Itemset: ['ELE17451', 'SNA62128'], Support: 186
# Itemset: ['ELE17451', 'ELE74482'], Support: 169
# Itemset: ['ELE17451', 'SNA57865'], Support: 101
# Itemset: ['ELE17451', 'GRO64900'], Support: 113
# Itemset: ['ELE17451', 'GRO71621'], Support: 290
# Itemset: ['ELE17451', 'DAI42493'], Support: 192
# Itemset: ['ELE17451', 'GRO32086'], Support: 108
# Itemset: ['ELE17451', 'ELE20847'], Support: 141
# Itemset: ['ELE17451', 'GRO46854'], Support: 209
# Itemset: ['ELE17451', 'ELE59028'], Support: 118
# Itemset: ['ELE17451', 'FRO99372'], Support: 115
# Itemset: ['ELE17451', 'SNA40784'], Support: 104
# Itemset: ['ELE17451', 'DAI55148'], Support: 305
# Itemset: ['ELE17451', 'DAI22240'], Support: 105
# Itemset: ['ELE17451', 'ELE92920'], Support: 228
# Itemset: ['ELE17451', 'ELE92920', 'DAI85309'], Support: 106
# Itemset: ['ELE17451', 'DAI85309'], Support: 106
# Itemset: ['ELE17451', 'GRO83463'], Support: 106
# Itemset: ['ELE17451', 'DAI23334'], Support: 100
# Itemset: ['ELE17451', 'FRO99783'], Support: 108
# Itemset: ['ELE17451', 'DAI87448'], Support: 111
# Itemset: ['ELE17451', 'DAI92600'], Support: 204
# Itemset: ['ELE17451', 'DAI92600', 'DAI42083'], Support: 117
# Itemset: ['ELE17451', 'DAI42083'], Support: 117
# Itemset: ['SNA90258'], Support: 113
# Itemset: ['GRO99222'], Support: 148
# Itemset: ['GRO12298'], Support: 385
# Itemset: ['SNA11465'], Support: 142
# Itemset: ['ELE26917'], Support: 314
# Itemset: ['ELE26917', 'DAI62779'], Support: 160
# Itemset: ['ELE52966'], Support: 380
# Itemset: ['SNA30755'], Support: 111
# Itemset: ['SNA80192'], Support: 258
# Itemset: ['GRO73461'], Support: 580
# Itemset: ['GRO73461', 'GRO30386'], Support: 103
# Itemset: ['GRO73461', 'FRO40251'], Support: 159
# Itemset: ['GRO73461', 'DAI75645'], Support: 121
# Itemset: ['DAI22896'], Support: 193
# Itemset: ['SNA99873'], Support: 270
# Itemset: ['FRO86643'], Support: 235
# Itemset: ['ELE37798'], Support: 534
# Itemset: ['GRO56989'], Support: 129
# Itemset: ['SNA69641'], Support: 599
# Itemset: ['FRO78087'], Support: 218
# Itemset: ['GRO39357'], Support: 296
# Itemset: ['ELE11375'], Support: 214
# Itemset: ['DAI54444'], Support: 401
# Itemset: ['DAI50921'], Support: 350
# Itemset: ['ELE59935'], Support: 181
# Itemset: ['SNA85662'], Support: 349
# Itemset: ['SNA91554'], Support: 208
# Itemset: ['DAI22177'], Support: 203
# Itemset: ['DAI14125'], Support: 163
# Itemset: ['DAI46755'], Support: 255
# Itemset: ['DAI46755', 'FRO81176'], Support: 148
# Itemset: ['FRO81176'], Support: 148
# Itemset: ['ELE66810'], Support: 154
# Itemset: ['DAI49199'], Support: 664
# Itemset: ['GRO94758'], Support: 227
# Itemset: ['SNA47306'], Support: 695
# Itemset: ['SNA47306', 'GRO36567'], Support: 102
# Itemset: ['GRO36567'], Support: 102
# Itemset: ['DAI87514'], Support: 254
# Itemset: ['GRO48282'], Support: 184
# Itemset: ['GRO12935'], Support: 169
# Itemset: ['SNA55952'], Support: 123
# Itemset: ['DAI92253'], Support: 293
# Itemset: ['DAI48891'], Support: 121
# Itemset: ['ELE27376'], Support: 159
# Itemset: ['DAI38969'], Support: 785
# Itemset: ['DAI50913'], Support: 448
# Itemset: ['DAI50913', 'GRO33815'], Support: 137
# Itemset: ['ELE11111'], Support: 121
# Itemset: ['SNA66979'], Support: 703
# Itemset: ['SNA66979', 'ELE38289'], Support: 124
# Itemset: ['FRO92261'], Support: 127
# Itemset: ['FRO32293'], Support: 219
# Itemset: ['FRO98729'], Support: 664
# Itemset: ['DAI95741'], Support: 102
# Itemset: ['GRO30386'], Support: 103
# Itemset: ['FRO41069'], Support: 409
# Itemset: ['FRO16142'], Support: 152
# Itemset: ['DAI88808'], Support: 123
# Itemset: ['DAI35347'], Support: 158
# Itemset: ['SNA63157'], Support: 139
# Itemset: ['DAI22534'], Support: 287
# Itemset: ['SNA93860'], Support: 182
# Itemset: ['FRO19520'], Support: 133
# Itemset: ['FRO24098'], Support: 521
# Itemset: ['FRO98878'], Support: 157
# Itemset: ['SNA72163'], Support: 272
# Itemset: ['SNA72163', 'SNA59903'], Support: 127
# Itemset: ['SNA72163', 'DAI88807'], Support: 105
# Itemset: ['DAI55911'], Support: 127
# Itemset: ['FRO31317'], Support: 359
# Itemset: ['SNA59903'], Support: 127
# Itemset: ['FRO38366'], Support: 353
# Itemset: ['ELE20196'], Support: 545
# Itemset: ['GRO15017'], Support: 171
# Itemset: ['FRO98184'], Support: 112
# Itemset: ['GRO59710'], Support: 408
# Itemset: ['GRO59710', 'ELE32164'], Support: 202
# Itemset: ['GRO59710', 'ELE32164', 'DAI43223'], Support: 101
# Itemset: ['GRO59710', 'DAI43223'], Support: 101
# Itemset: ['ELE30182'], Support: 274
# Itemset: ['ELE30182', 'SNA24799'], Support: 114
# Itemset: ['ELE18435'], Support: 163
# Itemset: ['DAI63921'], Support: 188
# Itemset: ['DAI95860'], Support: 246
# Itemset: ['SNA18336'], Support: 267
# Itemset: ['SNA18336', 'ELE92920'], Support: 228
# Itemset: ['SNA18336', 'ELE92920', 'DAI85309'], Support: 106
# Itemset: ['SNA18336', 'DAI85309'], Support: 106
# Itemset: ['GRO39070'], Support: 145
# Itemset: ['ELE69204'], Support: 179
# Itemset: ['ELE66600'], Support: 168
# Itemset: ['FRO62970'], Support: 115
# Itemset: ['SNA83730'], Support: 379
# Itemset: ['DAI91290'], Support: 219
# Itemset: ['ELE14480'], Support: 146
# Itemset: ['GRO82070'], Support: 114
# Itemset: ['DAI62779'], Support: 160
# Itemset: ['GRO34288'], Support: 266
# Itemset: ['SNA55762'], Support: 303
# Itemset: ['DAI32480'], Support: 165
# Itemset: ['SNA14713'], Support: 188
# Itemset: ['ELE91337'], Support: 1289
# Itemset: ['SNA93641'], Support: 240
# Itemset: ['FRO61250'], Support: 102
# Itemset: ['GRO17442'], Support: 101
# Itemset: ['SNA43319'], Support: 432
# Itemset: ['GRO38983'], Support: 839
# Itemset: ['ELE68605'], Support: 115
# Itemset: ['SNA45677'], Support: 304
# Itemset: ['SNA93730'], Support: 320
# Itemset: ['SNA89670'], Support: 169
# Itemset: ['FRO78994'], Support: 569
# Itemset: ['ELE20166'], Support: 145
# Itemset: ['DAI84001'], Support: 363
# Itemset: ['SNA30579'], Support: 139
# Itemset: ['DAI52318'], Support: 282
# Itemset: ['SNA77101'], Support: 102
# Itemset: ['ELE12792'], Support: 159
# Itemset: ['ELE20347'], Support: 366
# Itemset: ['ELE28189'], Support: 361
# Itemset: ['ELE28189', 'FRO17734'], Support: 164
# Itemset: ['ELE63685'], Support: 176
# Itemset: ['DAI37607'], Support: 319
# Itemset: ['ELE22574'], Support: 131
# Itemset: ['GRO71615'], Support: 290
# Itemset: ['SNA56035'], Support: 148
# Itemset: ['DAI33885'], Support: 108
# Itemset: ['ELE86561'], Support: 735
# Itemset: ['SNA40408'], Support: 354
# Itemset: ['ELE21353'], Support: 430
# Itemset: ['ELE21353', 'FRO19221'], Support: 124
# Itemset: ['FRO40251'], Support: 159
# Itemset: ['GRO38636'], Support: 107
# Itemset: ['FRO43226'], Support: 583
# Itemset: ['FRO43226', 'DAI86167'], Support: 118
# Itemset: ['FRO43226', 'FRO48038'], Support: 105
# Itemset: ['GRO85051'], Support: 217
# Itemset: ['GRO85051', 'SNA80324'], Support: 158
# Itemset: ['DAI59508'], Support: 707
# Itemset: ['FRO99756'], Support: 278
# Itemset: ['GRO84328'], Support: 299
# Itemset: ['ELE20398'], Support: 111
# Itemset: ['SNA62579'], Support: 106
# Itemset: ['FRO37380'], Support: 117
# Itemset: ['DAI25796'], Support: 127
# Itemset: ['DAI73122'], Support: 566
# Itemset: ['GRO69543'], Support: 128
# Itemset: ['ELE49863'], Support: 406
# Itemset: ['FRO53137'], Support: 190
# Itemset: ['ELE64231'], Support: 139
# Itemset: ['FRO21081'], Support: 436
# Itemset: ['FRO94523'], Support: 390
# Itemset: ['GRO15448'], Support: 237
# Itemset: ['FRO14171'], Support: 369
# Itemset: ['DAI74083'], Support: 375
# Itemset: ['SNA85241'], Support: 335
# Itemset: ['SNA85241', 'GRO44993'], Support: 121
# Itemset: ['GRO44993'], Support: 121
# Itemset: ['GRO61133'], Support: 209
# Itemset: ['FRO73056'], Support: 728
# Itemset: ['GRO81087'], Support: 262
# Itemset: ['SNA18183'], Support: 113
# Itemset: ['GRO35122'], Support: 154
# Itemset: ['DAI35798'], Support: 226
# Itemset: ['GRO67739'], Support: 360
# Itemset: ['SNA64534'], Support: 351
# Itemset: ['SNA35089'], Support: 111
# Itemset: ['ELE37770'], Support: 100
# Itemset: ['DAI70456'], Support: 427
# Itemset: ['ELE53126'], Support: 151
# Itemset: ['GRO61641'], Support: 320
# Itemset: ['ELE32164'], Support: 202
# Itemset: ['ELE32164', 'DAI43223'], Support: 101
# Itemset: ['DAI88807'], Support: 105
# Itemset: ['GRO92635'], Support: 136
# Itemset: ['ELE37048'], Support: 135
# Itemset: ['FRO27054'], Support: 229
# Itemset: ['ELE58409'], Support: 196
# Itemset: ['ELE62598'], Support: 153
# Itemset: ['GRO21487'], Support: 236
# Itemset: ['DAI43223'], Support: 101
# Itemset: ['ELE85027'], Support: 478
# Itemset: ['ELE37153'], Support: 132
# Itemset: ['ELE87710'], Support: 215
# Itemset: ['ELE53835'], Support: 237
# Itemset: ['FRO66272'], Support: 117
# Itemset: ['SNA46500'], Support: 104
# Itemset: ['SNA36781'], Support: 165
# Itemset: ['ELE66741'], Support: 387
# Itemset: ['SNA59061'], Support: 100
# Itemset: ['DAI88352'], Support: 105
# Itemset: ['FRO75591'], Support: 125
# Itemset: ['SNA79852'], Support: 108
# Itemset: ['DAI88079'], Support: 124
# Itemset: ['SNA80324'], Support: 158
# Itemset: ['FRO55003'], Support: 189
# Itemset: ['DAI29878'], Support: 114
# Itemset: ['SNA88283'], Support: 169
# Itemset: ['ELE38504'], Support: 271
# Itemset: ['DAI75645'], Support: 121
# Itemset: ['FRO92469'], Support: 165
# Itemset: ['SNA12663'], Support: 523
# Itemset: ['GRO38814'], Support: 160
# Itemset: ['FRO61611'], Support: 205
# Itemset: ['ELE92629'], Support: 336
# Itemset: ['ELE99737'], Support: 151
# Itemset: ['DAI66213'], Support: 109
# Itemset: ['SNA35732'], Support: 135
# Itemset: ['DAI86167'], Support: 118
# Itemset: ['FRO87415'], Support: 239
# Itemset: ['SNA83597'], Support: 130
# Itemset: ['SNA96271'], Support: 203
# Itemset: ['DAI83948'], Support: 830
# Itemset: ['DAI83948', 'GRO88511'], Support: 131
# Itemset: ['SNA89368'], Support: 231
# Itemset: ['DAI48126'], Support: 417
# Itemset: ['ELE49801'], Support: 663
# Itemset: ['FRO35904'], Support: 148
# Itemset: ['DAI67621'], Support: 384
# Itemset: ['ELE61940'], Support: 279
# Itemset: ['GRO50832'], Support: 608
# Itemset: ['FRO61161'], Support: 178
# Itemset: ['GRO68067'], Support: 651
# Itemset: ['ELE15527'], Support: 332
# Itemset: ['SNA97586'], Support: 178
# Itemset: ['ELE12845'], Support: 562
# Itemset: ['FRO85978'], Support: 173
# Itemset: ['SNA95666'], Support: 804
# Itemset: ['SNA24799'], Support: 114
# Itemset: ['SNA64706'], Support: 105
# Itemset: ['SNA99654'], Support: 234
# Itemset: ['FRO74605'], Support: 261
# Itemset: ['FRO53271'], Support: 182
# Itemset: ['SNA57913'], Support: 244
# Itemset: ['SNA55617'], Support: 389
# Itemset: ['DAI32836'], Support: 173
# Itemset: ['DAI94514'], Support: 129
# Itemset: ['SNA90094'], Support: 182
# Itemset: ['DAI91422'], Support: 185
# Itemset: ['SNA38068'], Support: 185
# Itemset: ['DAI51880'], Support: 375
# Itemset: ['ELE88263'], Support: 397
# Itemset: ['SNA17775'], Support: 167
# Itemset: ['DAI80076'], Support: 232
# Itemset: ['DAI13788'], Support: 213
# Itemset: ['ELE69630'], Support: 208
# Itemset: ['ELE74009'], Support: 231
# Itemset: ['GRO58055'], Support: 113
# Itemset: ['FRO90481'], Support: 163
# Itemset: ['SNA53983'], Support: 118
# Itemset: ['GRO35827'], Support: 218
# Itemset: ['SNA20554'], Support: 777
# Itemset: ['GRO56726'], Support: 218
# Itemset: ['ELE99211'], Support: 149
# Itemset: ['ELE24064'], Support: 139
# Itemset: ['ELE30196'], Support: 121
# Itemset: ['FRO35729'], Support: 438
# Itemset: ['FRO95943'], Support: 230
# Itemset: ['GRO52067'], Support: 315
# Itemset: ['DAI66473'], Support: 113
# Itemset: ['GRO73939'], Support: 103
# Itemset: ['FRO89565'], Support: 104
# Itemset: ['SNA49028'], Support: 150
# Itemset: ['GRO71279'], Support: 168
# Itemset: ['ELE65859'], Support: 284
# Itemset: ['SNA28093'], Support: 126
# Itemset: ['FRO41939'], Support: 408
# Itemset: ['DAI62356'], Support: 177
# Itemset: ['ELE34057'], Support: 168
# Itemset: ['SNA44451'], Support: 175
# Itemset: ['SNA44451', 'DAI18527'], Support: 102
# Itemset: ['ELE38289'], Support: 124
# Itemset: ['DAI58206'], Support: 164
# Itemset: ['GRO24246'], Support: 944
# Itemset: ['GRO24246', 'SNA30859'], Support: 119
# Itemset: ['SNA30859'], Support: 119
# Itemset: ['SNA12933'], Support: 189
# Itemset: ['DAI64292'], Support: 270
# Itemset: ['FRO19671'], Support: 391
# Itemset: ['SNA28860'], Support: 164
# Itemset: ['DAI96999'], Support: 145
# Itemset: ['ELE69675'], Support: 223
# Itemset: ['GRO58671'], Support: 120
# Itemset: ['ELE35632'], Support: 426
# Itemset: ['ELE38511'], Support: 218
# Itemset: ['DAI33336'], Support: 438
# Itemset: ['GRO33815'], Support: 137
# Itemset: ['ELE87456'], Support: 655
# Itemset: ['FRO66852'], Support: 262
# Itemset: ['ELE95803'], Support: 441
# Itemset: ['ELE88031'], Support: 277
# Itemset: ['FRO12719'], Support: 119
# Itemset: ['FRO75586'], Support: 151
# Itemset: ['ELE22970'], Support: 252
# Itemset: ['DAI26390'], Support: 243
# Itemset: ['DAI45339'], Support: 159
# Itemset: ['FRO66216'], Support: 157
# Itemset: ['FRO80238'], Support: 142
# Itemset: ['GRO87006'], Support: 291
# Itemset: ['GRO57755'], Support: 427
# Itemset: ['SNA35625'], Support: 199
# Itemset: ['DAI15681'], Support: 132
# Itemset: ['ELE30327'], Support: 183
# Itemset: ['SNA52886'], Support: 130
# Itemset: ['GRO55545'], Support: 138
# Itemset: ['ELE32244'], Support: 342
# Itemset: ['ELE56788'], Support: 208
# Itemset: ['DAI31081'], Support: 230
# Itemset: ['GRO23573'], Support: 272
# Itemset: ['DAI49017'], Support: 158
# Itemset: ['GRO88324'], Support: 117
# Itemset: ['DAI83733'], Support: 296
# Itemset: ['DAI59546'], Support: 259
# Itemset: ['DAI27125'], Support: 225
# Itemset: ['SNA19378'], Support: 117
# Itemset: ['FRO80039'], Support: 356
# Itemset: ['FRO18274'], Support: 145
# Itemset: ['ELE20202'], Support: 317
# Itemset: ['ELE25077'], Support: 478
# Itemset: ['ELE25077', 'GRO89004'], Support: 215
# Itemset: ['ELE50913'], Support: 190
# Itemset: ['ELE30911'], Support: 322
# Itemset: ['DAI16732'], Support: 187
# Itemset: ['FRO74121'], Support: 179
# Itemset: ['SNA94104'], Support: 107
# Itemset: ['ELE76310'], Support: 102
# Itemset: ['GRO90585'], Support: 100
# Itemset: ['ELE49861'], Support: 397
# Itemset: ['ELE40371'], Support: 100
# Itemset: ['ELE55721'], Support: 169
# Itemset: ['ELE56095'], Support: 164
# Itemset: ['SNA62128'], Support: 186
# Itemset: ['ELE50215'], Support: 113
# Itemset: ['FRO25840'], Support: 182
# Itemset: ['DAI59609'], Support: 350
# Itemset: ['ELE74482'], Support: 169
# Itemset: ['ELE61961'], Support: 265
# Itemset: ['FRO49682'], Support: 156
# Itemset: ['SNA53220'], Support: 580
# Itemset: ['ELE24630'], Support: 321
# Itemset: ['ELE67409'], Support: 135
# Itemset: ['ELE88583'], Support: 328
# Itemset: ['ELE88583', 'GRO30912'], Support: 105
# Itemset: ['GRO30912'], Support: 105
# Itemset: ['SNA87482'], Support: 103
# Itemset: ['DAI20585'], Support: 120
# Itemset: ['SNA12085'], Support: 117
# Itemset: ['ELE87243'], Support: 205
# Itemset: ['SNA57865'], Support: 101
# Itemset: ['SNA74022'], Support: 286
# Itemset: ['SNA26242'], Support: 218
# Itemset: ['GRO89004'], Support: 215
# Itemset: ['GRO45654'], Support: 144
# Itemset: ['DAI56158'], Support: 153
# Itemset: ['GRO91660'], Support: 212
# Itemset: ['SNA71332'], Support: 541
# Itemset: ['DAI87412'], Support: 271
# Itemset: ['GRO20770'], Support: 137
# Itemset: ['FRO61354'], Support: 450
# Itemset: ['SNA44190'], Support: 437
# Itemset: ['GRO69388'], Support: 121
# Itemset: ['SNA67745'], Support: 151
# Itemset: ['SNA38067'], Support: 164
# Itemset: ['ELE36909'], Support: 321
# Itemset: ['SNA68538'], Support: 344
# Itemset: ['DAI69156'], Support: 316
# Itemset: ['DAI51778'], Support: 100
# Itemset: ['GRO93309'], Support: 108
# Itemset: ['SNA84284'], Support: 128
# Itemset: ['SNA17270'], Support: 236
# Itemset: ['ELE11909'], Support: 131
# Itemset: ['GRO26160'], Support: 154
# Itemset: ['GRO64900'], Support: 113
# Itemset: ['GRO71621'], Support: 290
# Itemset: ['ELE86306'], Support: 221
# Itemset: ['FRO71085'], Support: 337
# Itemset: ['FRO47796'], Support: 102
# Itemset: ['SNA29014'], Support: 384
# Itemset: ['GRO65522'], Support: 288
# Itemset: ['DAI13266'], Support: 181
# Itemset: ['GRO82670'], Support: 459
# Itemset: ['SNA11790'], Support: 115
# Itemset: ['SNA46873'], Support: 229
# Itemset: ['DAI48423'], Support: 218
# Itemset: ['ELE60861'], Support: 127
# Itemset: ['DAI11778'], Support: 117
# Itemset: ['DAI87507'], Support: 213
# Itemset: ['DAI67189'], Support: 280
# Itemset: ['FRO33641'], Support: 146
# Itemset: ['GRO83111'], Support: 130
# Itemset: ['FRO42750'], Support: 186
# Itemset: ['GRO67714'], Support: 127
# Itemset: ['ELE78169'], Support: 558
# Itemset: ['DAI89320'], Support: 200
# Itemset: ['SNA41431'], Support: 144
# Itemset: ['DAI42493'], Support: 192
# Itemset: ['ELE16038'], Support: 226
# Itemset: ['FRO47962'], Support: 306
# Itemset: ['ELE18198'], Support: 256
# Itemset: ['ELE42696'], Support: 200
# Itemset: ['ELE12951'], Support: 106
# Itemset: ['FRO87724'], Support: 208
# Itemset: ['GRO61273'], Support: 439
# Itemset: ['GRO88511'], Support: 131
# Itemset: ['FRO17734'], Support: 164
# Itemset: ['ELE11160'], Support: 307
# Itemset: ['DAI11223'], Support: 155
# Itemset: ['GRO20227'], Support: 163
# Itemset: ['DAI53152'], Support: 195
# Itemset: ['DAI93865'], Support: 208
# Itemset: ['SNA30533'], Support: 332
# Itemset: ['GRO32086'], Support: 108
# Itemset: ['FRO49726'], Support: 118
# Itemset: ['FRO91449'], Support: 149
# Itemset: ['ELE59541'], Support: 179
# Itemset: ['GRO18367'], Support: 581
# Itemset: ['FRO18565'], Support: 394
# Itemset: ['SNA54435'], Support: 325
# Itemset: ['ELE20847'], Support: 141
# Itemset: ['FRO73337'], Support: 166
# Itemset: ['SNA62046'], Support: 115
# Itemset: ['SNA88543'], Support: 147
# Itemset: ['GRO52116'], Support: 203
# Itemset: ['DAI18805'], Support: 163
# Itemset: ['GRO46854'], Support: 209
# Itemset: ['DAI31893'], Support: 220
# Itemset: ['DAI47529'], Support: 304
# Itemset: ['FRO74324'], Support: 220
# Itemset: ['FRO48920'], Support: 294
# Itemset: ['ELE54144'], Support: 163
# Itemset: ['ELE72565'], Support: 249
# Itemset: ['DAI53495'], Support: 137
# Itemset: ['GRO76157'], Support: 494
# Itemset: ['FRO47183'], Support: 151
# Itemset: ['FRO32147'], Support: 169
# Itemset: ['ELE73453'], Support: 188
# Itemset: ['SNA66583'], Support: 261
# Itemset: ['DAI29159'], Support: 442
# Itemset: ['GRO29389'], Support: 138
# Itemset: ['SNA61380'], Support: 260
# Itemset: ['SNA50789'], Support: 588
# Itemset: ['ELE59028'], Support: 118
# Itemset: ['DAI94415'], Support: 116
# Itemset: ['ELE31499'], Support: 111
# Itemset: ['FRO83374'], Support: 285
# Itemset: ['DAI56641'], Support: 152
# Itemset: ['FRO14040'], Support: 124
# Itemset: ['GRO18468'], Support: 193
# Itemset: ['ELE42974'], Support: 170
# Itemset: ['FRO99372'], Support: 115
# Itemset: ['GRO95519'], Support: 400
# Itemset: ['GRO92215'], Support: 102
# Itemset: ['SNA16036'], Support: 262
# Itemset: ['SNA28601'], Support: 109
# Itemset: ['GRO46627'], Support: 192
# Itemset: ['FRO17134'], Support: 119
# Itemset: ['SNA90161'], Support: 101
# Itemset: ['GRO57279'], Support: 233
# Itemset: ['GRO93333'], Support: 153
# Itemset: ['SNA58341'], Support: 525
# Itemset: ['ELE73604'], Support: 216
# Itemset: ['SNA40784'], Support: 104
# Itemset: ['ELE27303'], Support: 123
# Itemset: ['GRO21047'], Support: 126
# Itemset: ['DAI55148'], Support: 305
# Itemset: ['FRO66881'], Support: 119
# Itemset: ['FRO64059'], Support: 179
# Itemset: ['GRO70959'], Support: 326
# Itemset: ['FRO77633'], Support: 223
# Itemset: ['SNA38046'], Support: 239
# Itemset: ['DAI37288'], Support: 181
# Itemset: ['DAI14181'], Support: 110
# Itemset: ['DAI59441'], Support: 108
# Itemset: ['GRO56701'], Support: 185
# Itemset: ['DAI74315'], Support: 286
# Itemset: ['SNA37363'], Support: 103
# Itemset: ['FRO53088'], Support: 285
# Itemset: ['DAI41952'], Support: 168
# Itemset: ['ELE55848'], Support: 148
# Itemset: ['DAI43063'], Support: 169
# Itemset: ['DAI94445'], Support: 149
# Itemset: ['GRO81647'], Support: 490
# Itemset: ['SNA49107'], Support: 484
# Itemset: ['ELE74410'], Support: 220
# Itemset: ['ELE53470'], Support: 271
# Itemset: ['ELE34030'], Support: 140
# Itemset: ['ELE60182'], Support: 198
# Itemset: ['SNA66588'], Support: 109
# Itemset: ['DAI99319'], Support: 232
# Itemset: ['DAI43868'], Support: 296
# Itemset: ['DAI43868', 'SNA82528'], Support: 288
# Itemset: ['SNA37803'], Support: 212
# Itemset: ['FRO22809'], Support: 267
# Itemset: ['SNA82308'], Support: 136
# Itemset: ['GRO81900'], Support: 169
# Itemset: ['FRO57082'], Support: 182
# Itemset: ['GRO17075'], Support: 261
# Itemset: ['DAI91654'], Support: 131
# Itemset: ['FRO99751'], Support: 175
# Itemset: ['DAI63631'], Support: 201
# Itemset: ['SNA96466'], Support: 506
# Itemset: ['FRO68870'], Support: 186
# Itemset: ['FRO48038'], Support: 105
# Itemset: ['DAI14470'], Support: 153
# Itemset: ['DAI22240'], Support: 105
# Itemset: ['FRO32801'], Support: 101
# Itemset: ['DAI63507'], Support: 151
# Itemset: ['SNA92435'], Support: 331
# Itemset: ['ELE38536'], Support: 226
# Itemset: ['ELE74567'], Support: 139
# Itemset: ['DAI88088'], Support: 394
# Itemset: ['GRO94173'], Support: 474
# Itemset: ['ELE69750'], Support: 342
# Itemset: ['FRO49827'], Support: 273
# Itemset: ['FRO89355'], Support: 136
# Itemset: ['SNA51149'], Support: 119
# Itemset: ['FRO44046'], Support: 213
# Itemset: ['ELE81534'], Support: 213
# Itemset: ['DAI23411'], Support: 102
# Itemset: ['ELE36588'], Support: 101
# Itemset: ['ELE92920'], Support: 228
# Itemset: ['ELE92920', 'DAI85309'], Support: 106
# Itemset: ['DAI50189'], Support: 103
# Itemset: ['FRO64631'], Support: 341
# Itemset: ['FRO13478'], Support: 276
# Itemset: ['SNA82528'], Support: 288
# Itemset: ['GRO46839'], Support: 225
# Itemset: ['SNA29146'], Support: 145
# Itemset: ['DAI13194'], Support: 116
# Itemset: ['SNA53368'], Support: 171
# Itemset: ['SNA81024'], Support: 222
# Itemset: ['GRO88505'], Support: 521
# Itemset: ['ELE36333'], Support: 268
# Itemset: ['SNA12350'], Support: 113
# Itemset: ['GRO12870'], Support: 106
# Itemset: ['DAI74977'], Support: 108
# Itemset: ['FRO26482'], Support: 332
# Itemset: ['SNA57752'], Support: 127
# Itemset: ['DAI32718'], Support: 173
# Itemset: ['SNA88091'], Support: 168
# Itemset: ['FRO87855'], Support: 131
# Itemset: ['SNA80230'], Support: 201
# Itemset: ['SNA42528'], Support: 489
# Itemset: ['SNA59228'], Support: 155
# Itemset: ['DAI72236'], Support: 280
# Itemset: ['SNA18094'], Support: 109
# Itemset: ['FRO23748'], Support: 209
# Itemset: ['SNA71244'], Support: 195
# Itemset: ['FRO44973'], Support: 142
# Itemset: ['ELE24694'], Support: 107
# Itemset: ['GRO89148'], Support: 228
# Itemset: ['DAI91392'], Support: 194
# Itemset: ['SNA74222'], Support: 158
# Itemset: ['GRO97621'], Support: 125
# Itemset: ['ELE35159'], Support: 202
# Itemset: ['ELE61844'], Support: 187
# Itemset: ['DAI20027'], Support: 114
# Itemset: ['DAI85054'], Support: 116
# Itemset: ['GRO29598'], Support: 214
# Itemset: ['FRO79022'], Support: 751
# Itemset: ['DAI28743'], Support: 214
# Itemset: ['FRO64787'], Support: 130
# Itemset: ['FRO97732'], Support: 260
# Itemset: ['GRO13844'], Support: 203
# Itemset: ['DAI74874'], Support: 132
# Itemset: ['SNA12690'], Support: 210
# Itemset: ['GRO39661'], Support: 205
# Itemset: ['SNA31619'], Support: 281
# Itemset: ['FRO11140'], Support: 103
# Itemset: ['DAI85309'], Support: 106
# Itemset: ['FRO87622'], Support: 103
# Itemset: ['SNA90993'], Support: 100
# Itemset: ['FRO55161'], Support: 158
# Itemset: ['GRO75758'], Support: 163
# Itemset: ['ELE30933'], Support: 327
# Itemset: ['ELE36642'], Support: 162
# Itemset: ['DAI13902'], Support: 233
# Itemset: ['FRO71487'], Support: 194
# Itemset: ['GRO96567'], Support: 131
# Itemset: ['ELE88539'], Support: 197
# Itemset: ['DAI54320'], Support: 160
# Itemset: ['DAI26369'], Support: 175
# Itemset: ['ELE15428'], Support: 118
# Itemset: ['FRO62357'], Support: 159
# Itemset: ['GRO67376'], Support: 132
# Itemset: ['ELE63143'], Support: 159
# Itemset: ['SNA43571'], Support: 125
# Itemset: ['DAI74112'], Support: 113
# Itemset: ['SNA93177'], Support: 132
# Itemset: ['SNA24061'], Support: 121
# Itemset: ['SNA87537'], Support: 167
# Itemset: ['GRO94871'], Support: 103
# Itemset: ['GRO33356'], Support: 132
# Itemset: ['ELE60381'], Support: 368
# Itemset: ['FRO71033'], Support: 104
# Itemset: ['SNA30908'], Support: 136
# Itemset: ['DAI34857'], Support: 163
# Itemset: ['DAI53110'], Support: 239
# Itemset: ['SNA81556'], Support: 110
# Itemset: ['DAI52509'], Support: 158
# Itemset: ['SNA97370'], Support: 119
# Itemset: ['ELE64691'], Support: 106
# Itemset: ['FRO57542'], Support: 175
# Itemset: ['DAI68241'], Support: 103
# Itemset: ['SNA77634'], Support: 131
# Itemset: ['SNA28607'], Support: 103
# Itemset: ['FRO19221'], Support: 124
# Itemset: ['GRO83463'], Support: 106
# Itemset: ['ELE12808'], Support: 100
# Itemset: ['SNA17634'], Support: 131
# Itemset: ['SNA13853'], Support: 117
# Itemset: ['FRO68757'], Support: 107
# Itemset: ['ELE69552'], Support: 303
# Itemset: ['FRO31824'], Support: 223
# Itemset: ['GRO24757'], Support: 102
# Itemset: ['DAI77909'], Support: 125
# Itemset: ['SNA40058'], Support: 118
# Itemset: ['GRO74951'], Support: 237
# Itemset: ['SNA21851'], Support: 120
# Itemset: ['DAI42393'], Support: 118
# Itemset: ['DAI94679'], Support: 331
# Itemset: ['DAI94679', 'DAI83031'], Support: 141
# Itemset: ['DAI23334'], Support: 100
# Itemset: ['FRO73386'], Support: 119
# Itemset: ['ELE67905'], Support: 102
# Itemset: ['FRO36333'], Support: 124
# Itemset: ['GRO66628'], Support: 102
# Itemset: ['GRO26124'], Support: 106
# Itemset: ['GRO91630'], Support: 132
# Itemset: ['FRO91992'], Support: 115
# Itemset: ['GRO32524'], Support: 106
# Itemset: ['DAI50895'], Support: 197
# Itemset: ['GRO43332'], Support: 137
# Itemset: ['GRO42566'], Support: 132
# Itemset: ['ELE99724'], Support: 101
# Itemset: ['ELE69973'], Support: 107
# Itemset: ['GRO65025'], Support: 151
# Itemset: ['DAI18527'], Support: 102
# Itemset: ['DAI34472'], Support: 121
# Itemset: ['DAI83031'], Support: 141
# Itemset: ['SNA56249'], Support: 222
# Itemset: ['FRO31077'], Support: 203
# Itemset: ['DAI39727'], Support: 156
# Itemset: ['GRO96342'], Support: 158
# Itemset: ['GRO75369'], Support: 166
# Itemset: ['DAI72502'], Support: 183
# Itemset: ['FRO65488'], Support: 145
# Itemset: ['ELE16299'], Support: 227
# Itemset: ['ELE50759'], Support: 122
# Itemset: ['ELE31307'], Support: 102
# Itemset: ['DAI43747'], Support: 233
# Itemset: ['ELE93905'], Support: 109
# Itemset: ['FRO99783'], Support: 108
# Itemset: ['GRO22957'], Support: 134
# Itemset: ['SNA12342'], Support: 103
# Itemset: ['GRO15683'], Support: 121
# Itemset: ['DAI87448'], Support: 111
# Itemset: ['FRO48055'], Support: 182
# Itemset: ['FRO98006'], Support: 121
# Itemset: ['GRO67806'], Support: 248
# Itemset: ['GRO37797'], Support: 155
# Itemset: ['GRO99635'], Support: 120
# Itemset: ['SNA40078'], Support: 152
# Itemset: ['ELE27021'], Support: 251
# Itemset: ['SNA38584'], Support: 104
# Itemset: ['GRO85863'], Support: 115
# Itemset: ['ELE81987'], Support: 230
# Itemset: ['FRO17249'], Support: 117
# Itemset: ['GRO81045'], Support: 252
# Itemset: ['DAI16142'], Support: 132
# Itemset: ['ELE19549'], Support: 231
# Itemset: ['DAI92600'], Support: 204
# Itemset: ['DAI92600', 'DAI42083'], Support: 117
# Itemset: ['DAI42083'], Support: 117
# Itemset: ['ELE53386'], Support: 128
# Itemset: ['SNA92493'], Support: 153
# Itemset: ['FRO52457'], Support: 153

# %%
frequent_doubletons = []
frequent_triplets = []
for itemset, support in frequent_itemsets_dict.items():
    if len(itemset) == 2:
        frequent_doubletons.append((itemset, support))
    elif len(itemset) == 3:
        frequent_triplets.append((itemset, support))

# %%
print(frequent_doubletons)
# Out:
# [(('ELE17451', 'SNA90258'), 113), (('ELE17451', 'GRO99222'), 148), (('ELE17451', 'ELE26917'), 314), (('ELE17451', 'SNA30755'), 111), (('ELE17451', 'GRO73461'), 580), (('DAI22896', 'ELE17451'), 193), (('ELE17451', 'SNA99873'), 270), (('ELE17451', 'GRO56989'), 129), (('ELE17451', 'FRO78087'), 218), (('ELE17451', 'ELE59935'), 181), (('DAI22177', 'ELE17451'), 203), (('ELE17451', 'ELE66810'), 154), (('ELE17451', 'GRO94758'), 227), (('ELE17451', 'SNA55952'), 123), (('DAI48891', 'ELE17451'), 121), (('ELE11111', 'ELE17451'), 121), (('ELE17451', 'FRO92261'), 127), (('ELE17451', 'FRO32293'), 219), (('DAI95741', 'ELE17451'), 102), (('ELE17451', 'GRO30386'), 103), (('ELE17451', 'FRO16142'), 152), (('DAI35347', 'ELE17451'), 158), (('ELE17451', 'SNA93860'), 182), (('ELE17451', 'SNA72163'), 272), (('DAI55911', 'ELE17451'), 127), (('ELE17451', 'FRO31317'), 359), (('ELE17451', 'SNA59903'), 127), (('ELE17451', 'GRO15017'), 171), (('ELE17451', 'FRO98184'), 112), (('ELE17451', 'GRO59710'), 408), (('DAI63921', 'ELE17451'), 188), (('ELE17451', 'SNA18336'), 267), (('ELE17451', 'ELE66600'), 168), (('DAI91290', 'ELE17451'), 219), (('ELE14480', 'ELE17451'), 146), (('DAI62779', 'ELE17451'), 160), (('ELE17451', 'SNA55762'), 303), (('ELE17451', 'ELE68605'), 115), (('ELE17451', 'SNA45677'), 304), (('ELE12792', 'ELE17451'), 159), (('ELE17451', 'FRO40251'), 159), (('ELE17451', 'GRO85051'), 217), (('ELE17451', 'ELE20398'), 111), (('ELE17451', 'GRO69543'), 128), (('ELE17451', 'GRO61133'), 209), (('ELE17451', 'GRO81087'), 262), (('ELE17451', 'GRO35122'), 154), (('ELE17451', 'ELE37770'), 100), (('ELE17451', 'ELE53126'), 151), (('ELE17451', 'ELE32164'), 202), (('DAI88807', 'ELE17451'), 105), (('ELE17451', 'ELE37048'), 135), (('ELE17451', 'ELE62598'), 153), (('ELE17451', 'GRO21487'), 236), (('DAI43223', 'ELE17451'), 101), (('ELE17451', 'FRO66272'), 117), (('ELE17451', 'SNA59061'), 100), (('DAI88352', 'ELE17451'), 105), (('DAI88079', 'ELE17451'), 124), (('ELE17451', 'SNA80324'), 158), (('ELE17451', 'SNA88283'), 169), (('DAI75645', 'ELE17451'), 121), (('ELE17451', 'FRO92469'), 165), (('ELE17451', 'GRO38814'), 160), (('ELE17451', 'ELE99737'), 151), (('ELE17451', 'SNA96271'), 203), (('ELE17451', 'FRO35904'), 148), (('ELE17451', 'FRO85978'), 173), (('ELE17451', 'FRO53271'), 182), (('ELE17451', 'SNA90094'), 182), (('ELE17451', 'SNA38068'), 185), (('ELE17451', 'ELE74009'), 231), (('ELE17451', 'GRO56726'), 218), (('ELE17451', 'FRO89565'), 104), (('ELE17451', 'ELE34057'), 168), (('ELE17451', 'FRO75586'), 151), (('ELE17451', 'ELE56788'), 208), (('DAI31081', 'ELE17451'), 230), (('ELE17451', 'GRO88324'), 117), (('DAI83733', 'ELE17451'), 296), (('ELE17451', 'FRO80039'), 356), (('ELE17451', 'SNA62128'), 186), (('ELE17451', 'ELE74482'), 169), (('ELE17451', 'SNA57865'), 101), (('ELE17451', 'GRO64900'), 113), (('ELE17451', 'GRO71621'), 290), (('DAI42493', 'ELE17451'), 192), (('ELE17451', 'GRO32086'), 108), (('ELE17451', 'ELE20847'), 141), (('ELE17451', 'GRO46854'), 209), (('ELE17451', 'ELE59028'), 118), (('ELE17451', 'FRO99372'), 115), (('ELE17451', 'SNA40784'), 104), (('DAI55148', 'ELE17451'), 305), (('DAI22240', 'ELE17451'), 105), (('ELE17451', 'ELE92920'), 228), (('DAI85309', 'ELE17451'), 106), (('ELE17451', 'GRO83463'), 106), (('DAI23334', 'ELE17451'), 100), (('ELE17451', 'FRO99783'), 108), (('DAI87448', 'ELE17451'), 111), (('DAI92600', 'ELE17451'), 204), (('DAI42083', 'ELE17451'), 117), (('DAI62779', 'ELE26917'), 160), (('GRO30386', 'GRO73461'), 103), (('FRO40251', 'GRO73461'), 159), (('DAI75645', 'GRO73461'), 121), (('DAI46755', 'FRO81176'), 148), (('GRO36567', 'SNA47306'), 102), (('DAI50913', 'GRO33815'), 137), (('ELE38289', 'SNA66979'), 124), (('SNA59903', 'SNA72163'), 127), (('DAI88807', 'SNA72163'), 105), (('ELE32164', 'GRO59710'), 202), (('DAI43223', 'GRO59710'), 101), (('ELE30182', 'SNA24799'), 114), (('ELE92920', 'SNA18336'), 228), (('DAI85309', 'SNA18336'), 106), (('ELE28189', 'FRO17734'), 164), (('ELE21353', 'FRO19221'), 124), (('DAI86167', 'FRO43226'), 118), (('FRO ...

# %%
ass_double_rules = {}
for itemset, support in frequent_doubletons:
    item1, item2 = itemset
    
    ass_double_rules[(item1, item2)] = support / get_full_support([item1], baskets)
    ass_double_rules[(item2, item1)] = support / get_full_support([item2], baskets)

sorted_rules = sorted(ass_double_rules.items(), key=lambda x: x[1], reverse=True)
top_doubleton_rules = [rule for rule in sorted_rules if rule[1] > 0.5]

print(f"Top rules with confidence above 0.5:\n {top_doubleton_rules}")
print(f"\nNumber of top rules: {len(top_doubleton_rules)}")
# Out:
# Top rules with confidence above 0.5:
#  [(('DAI43868', 'SNA82528'), 0.972972972972973), (('GRO89004', 'ELE25077'), 0.698051948051948), (('SNA44451', 'DAI18527'), 0.5828571428571429), (('FRO17734', 'ELE28189'), 0.5815602836879432), (('DAI46755', 'FRO81176'), 0.5803921568627451), (('SNA30859', 'GRO24246'), 0.53125)]
#
# Number of top rules: 6

# %%
ass_triplet_rules = {}
for itemset, support in frequent_triplets:
    item1, item2, item3 = itemset
    ass_triplet_rules[(item1, item2, item3)] = support / get_full_support([item1, item2], baskets)
    ass_triplet_rules[(item1, item3, item2)] = support / get_full_support([item1, item3], baskets)
    ass_triplet_rules[(item2, item3, item1)] = support / get_full_support([item2, item3], baskets)

sorted_triplet_rules = sorted(ass_triplet_rules.items(), key=lambda x: x[1], reverse=True)
top_triplet_rules = [rule for rule in sorted_triplet_rules if rule[1]>0.5]
print(f"Top rules with confidence above 0.5:\n {top_triplet_rules}")
print(f"\n Number of top rules: {len(top_triplet_rules)}")
# Out:
# Top rules with confidence above 0.5:
#  [(('ELE17451', 'SNA18336', 'ELE92920'), 0.8539325842696629), (('ELE17451', 'GRO85051', 'SNA80324'), 0.728110599078341), (('DAI42083', 'ELE17451', 'DAI92600'), 0.6324324324324324), (('DAI85309', 'SNA18336', 'ELE17451'), 0.6127167630057804), (('DAI85309', 'SNA18336', 'ELE92920'), 0.6127167630057804), (('ELE17451', 'ELE92920', 'SNA18336'), 0.59375), (('DAI92600', 'ELE17451', 'DAI42083'), 0.5735294117647058), (('DAI85309', 'ELE92920', 'ELE17451'), 0.527363184079602), (('DAI85309', 'ELE92920', 'SNA18336'), 0.527363184079602), (('ELE17451', 'ELE26917', 'DAI62779'), 0.5095541401273885), (('ELE92920', 'SNA18336', 'ELE17451'), 0.5010989010989011)]
#
#  Number of top rules: 11
